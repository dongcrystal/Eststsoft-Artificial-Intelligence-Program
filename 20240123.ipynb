# %%
print("hello world") #주석
# Out:
# hello world

# %%
import pandas as pd

file_path = '/content/house.price.2.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#     ID    평수    연식  가격  Unnamed: 4
# 0  1.0  34.0   5.0  5.0        NaN
# 1  2.0  25.0   5.0  2.5        NaN
# 2  3.0  30.0   2.0  4.0        NaN
# 3  4.0  38.0  20.0  3.0        NaN
# 4  5.0  44.0  12.0  3.3        NaN
